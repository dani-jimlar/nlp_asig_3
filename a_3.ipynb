# %%
from typing import Sequence, Tuple, TypeVar
import nltk

# nltk.download('brown')
from nltk.corpus import brown
import numpy as np

Q = TypeVar("Q")
V = TypeVar("V")

# %%
corpus = nltk.corpus.brown.tagged_sents(tagset="universal")[:10000]
corpus
# corps=nltk.corpus.brown.tagged_sents(tagset='universal')[10150:10153]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/danielajimenez/nlp_asig_3/a_3.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/danielajimenez/nlp_asig_3/a_3.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> corpus = nltk.corpus.brown.tagged_sents(tagset='universal')[:10000]
#       <a href='vscode-notebook-cell:/Users/danielajimenez/nlp_asig_3/a_3.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> corpus
#       <a href='vscode-notebook-cell:/Users/danielajimenez/nlp_asig_3/a_3.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> #corps=nltk.corpus.brown.tagged_sents(tagset='universal')[10150:10153]
#
# File ~/miniconda3/lib/python3.11/site-packages/nltk/collections.py:162, in AbstractLazySequence.__getitem__(self, i)
#     157 """
#     158 Return the *i* th token in the corpus file underlying this
#     159 corpus view.  Negative indices and spans are both supported.
#     160 """
# ...
